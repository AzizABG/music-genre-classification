# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dist = np.load('distance_matrix.npy')

# %%
dist
# Out:
# array([[    0.        , 30752.91901224, 15686.05145074, ...,
#         21303.37806153,   571.45292683,  4471.89785772],
#        [    0.        ,     0.        , 15085.44139125, ...,
#          9505.67115864, 30252.76859372, 26297.97844103],
#        [    0.        ,     0.        ,     0.        , ...,
#          5683.70923816, 15180.65148123, 11233.43793035],
#        ...,
#        [    0.        ,     0.        ,     0.        , ...,
#             0.        , 20802.44932529, 16864.08941007],
#        [    0.        ,     0.        ,     0.        , ...,
#             0.        ,     0.        ,  3973.80794427],
#        [    0.        ,     0.        ,     0.        , ...,
#             0.        ,     0.        ,     0.        ]])

# %%
sns.heatmap(dist)
# Out:
# <Axes: >
