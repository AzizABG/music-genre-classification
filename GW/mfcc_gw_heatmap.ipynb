# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dist = np.load('distance_matrix_mfcc.npy')

# %%
dist
# Out:
# array([[   0.        ,  496.04650145,  196.4508777 , ..., 1384.62961828,
#          953.84667011,  508.40574873],
#        [   0.        ,    0.        ,  358.63481403, ...,  913.79178976,
#          508.38042708,  822.5197816 ],
#        [   0.        ,    0.        ,    0.        , ..., 1210.67151461,
#          777.97402627,  645.2375911 ],
#        ...,
#        [   0.        ,    0.        ,    0.        , ...,    0.        ,
#          513.87497782, 1705.60676545],
#        [   0.        ,    0.        ,    0.        , ...,    0.        ,
#            0.        , 1247.02596945],
#        [   0.        ,    0.        ,    0.        , ...,    0.        ,
#            0.        ,    0.        ]])

# %%
sns.heatmap(dist)
plt.savefig('similarity_mfccs_distance.png')
